# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c']
# cria lista

# %%
minha_lista = [10, 20,30]
arr = np.array([10,20,30])
#cria um array numpy
d = {'a':10, 'b':20 , 'c':30}
# cria chave valor ligando labels com a lista de nums

# %%
pd.Series(data = minha_lista, index =labels)
# cria um series onde os labels e a lista de nums estao conectados
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
series = pd.Series(data = minha_lista, index =labels)

# %%
series['b']
# acessa o indice b de series e retorna o valor corresnponde ao indice
# Out:
# np.int64(20)

# %%
pd.Series(minha_lista, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr, labels)
# cria com arr da mesma forma
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1 = pd.Series([1,2,3,4], index=['EUA', 'Alemanha', 'URSS','Japão'])
# cria umm series e adc em ser1

# %%
ser1
# Out:
# EUA         1
# Alemanha    2
# URSS        3
# Japão       4
# dtype: int64

# %%
ser2 = pd.Series([1,2,3,4], index=[ 'Alemanha','EUA', 'Italia','Japão'])
# cria ser 2 com indice diferente de ser1

# %%
ser2
# Out:
# Alemanha    1
# EUA         2
# Italia      3
# Japão       4
# dtype: int64

# %%
ser1 + ser2
# como em ser1 tem URSS e em ser2 nao tem, tem a Italia, a soma deles vai como dar Nan pois nao e encontrado o indice igual para assim somar os dois series
# Out:
# Alemanha    3.0
# EUA         3.0
# Italia      NaN
# Japão       8.0
# URSS        NaN
# dtype: float64
