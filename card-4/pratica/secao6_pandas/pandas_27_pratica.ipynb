# %%
import numpy as np
import pandas as pd

# %%
lt = ['julia', 'joao', 'maria', 'pedro', 'ana']
# cria lista

# %%
notas = [10, 70,40, 100, 50]
# cria uma lista de notas
d = {'julia':10, 'joao':70 , 'maria':40, 'pedro':100, 'ana':50}
# cria chave valor ligando labels com a lista de nums

# %%
ser= pd.Series(data = notas, index =lt)
# cria um series com as notas dos alunos

# %%
ser['joao']
# acessa o indice joao de series e retorna o valor correspondente ao indice
# Out:
# np.int64(70)

# %%
f = {'julia':10, 'joao':70 , 'maria':40, 'pedro':100}

# %%
ser2 = pd.Series(data = f)
# cria um series com as notas dos alunos usando dicionario

# %%
ser + ser2
# como no ser2 nao tem ana ele coloca como Nan
# Out:
# ana        NaN
# joao     140.0
# julia     20.0
# maria     80.0
# pedro    200.0
# dtype: float64
