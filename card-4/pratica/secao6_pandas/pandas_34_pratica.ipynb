# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc', 'def', 'ghi', 'xyz']})

# %%
df.head()
# mostra as 5 primeiras linhas do DataFrame

# %%
df.head(2)
#mostra as 2 primeiras linhas do DataFrame

# %%
df['col2'].unique()
# pega os valores unicos, tirando as duplicadas

# %%
df['col2'].nunique()
# conta quantos numeros unicos a coluna2 tem

# %%
df['col2'].value_counts()
# mostra quantos valores cada valor tem

# %%
def vezes2(x):
    return x*4

# %%
df['col1'].apply(vezes2)
# aplica a funcao para cada elemento da col1

# %%
del df['col2']
# deleta a coluna 2 do dataframe

# %%
df.columns

# %%
df.sort_values(by='col3', inplace=True)
# ordena a coluna 3

# %%
df

# %%
df.isnull().sum()
# conta quantos valores nulos existem em cada coluna

# %%
data = {
    'A': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'],
    'B': ['one', 'one', 'two', 'two', 'one', 'one'],
    'C': ['x', 'y', 'x', 'y', 'x', 'y'],
    'D': [1, 3, 2, 5, 4, 1]
}

df = pd.DataFrame(data)

# %%
df

# %%
df.pivot_table(values='D', index=['A', 'B'], columns=['C'])
# faz uma tabela pivo com os valores da coluna D indexando pelas colunas A e B
