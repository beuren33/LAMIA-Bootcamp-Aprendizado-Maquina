# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('exemplo.csv')
#le o arquivo csv e o transforma em um datafrae

# %%
df
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df = df *3

# %%
df.to_csv('exemplo2.csv', index=False)
# exporta o dataframe para um arquivo cs sem o index

# %%
df = pd.read_excel('excel.xlsx', sheet_name='Sheet1')
# le o arq excel e transforma em dataframe

# %%
df.to_excel('exemplo2.xlsx')

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')
# faz um scrapping em uma pagina web
