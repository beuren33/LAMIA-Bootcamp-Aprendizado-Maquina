# %%
from numpy import random
random.seed(0)

totals = {20:0, 30:0, 40:0, 50:0, 60:0, 70:0}
purchases = {20:0, 30:0, 40:0, 50:0, 60:0, 70:0}
totalPurchases = 0
for _ in range(100000):
    ageDecade = random.choice([20, 30, 40, 50, 60, 70])
    purchaseProbability = float(ageDecade) / 100.0
    totals[ageDecade] += 1
    if (random.random() < purchaseProbability):
        totalPurchases += 1
        purchases[ageDecade] += 1

# %%
# quantas pessoas caíram em cada faaix
totals

# %%
# quantas compraram por faixa
purchases

# %%
# total geral de compras
totalPurchases

# %%
# P(compra | 30s) probabilidade condicional 
PEF = float(purchases[30]) / float(totals[30])
print('P(purchase | 30s): ' + str(PEF))

# %%
PF = float(totals[30]) / 100000.0
print("P(30's): " + str(PF))

# %%
# P(30s e compra) juntando dos dois eventos
print("P(30's, Purchase)" + str(float(purchases[30]) / 100000.0))

# %%
# testando se P(30s)*P(compra) da igual a P(30s,compra)
print("P(30's)P(Purchase)" + str(PE * PF))

# %%
# refazendo a conta manual da condicional
print((purchases[30] / 100000.0) / PF)

# %% [markdown]
# # Exercise

# %%
pra# agora prob de compra fixa em 0.4  todo mundo, testando independencia de verdade
from numpy import random
random.seed(0)

totals = {20:0, 30:0, 40:0, 50:0, 60:0, 70:0}
purchases = {20:0, 30:0, 40:0, 50:0, 60:0, 70:0}
totalPurchases = 0
for _ in range(100000):
    ageDecade = random.choice([20, 30, 40, 50, 60, 70])
    purchaseProbability = 0.4
    totals[ageDecade] += 1
    if (random.random() < purchaseProbability):
        totalPurchases += 1
        purchases[ageDecade] += 1

# %%
# se for independente esse valor deve ficar perto de 0.5
PEF = float(purchases[30]) / float(totals[30])
print("P(purchase | 30s): " + str(PEF))

# %%
# prob geral de compra
PE = float(totalPurchases) / 100000.0
print("P(Purchase):" + str(PE))
